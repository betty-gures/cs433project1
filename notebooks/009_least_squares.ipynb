# %% [markdown]
# # 009: Least Squares Implementation

# %%
import sys

import matplotlib.pyplot as plt
import numpy as np

sys.path.append("../")
from metrics import f_score, auc_roc
from models import OrdinaryLeastSquares
from visualizations import plot_roc

# %load_ext autoreload
# %autoreload 2

# %%
train = np.load("../data/dataset_prep/train.npz")
x_train = train["x_train"]
y_train = train["y_train"]

# %%
model = OrdinaryLeastSquares(weighting=False)
model.train(x_train, y_train, metric=f_score, verbose=True)
# Out:
# Best threshold: 0.21608040201005024 with score 0.4225963435485992

# %%
pred = model.predict(x_train, scores=True)  # get scores instead of binary predictions
plt.hist(pred)
plt.show()

# %%
auc_roc(pred, y_train)
# Out:
# 0.8550768917420891

# %%
plot_roc(pred, y_train)
# Out:
# Threshold: 0.00, F1 Score: 0.2093
# Threshold: 0.01, F1 Score: 0.2223
# Threshold: 0.02, F1 Score: 0.2352
# Threshold: 0.03, F1 Score: 0.2484
# Threshold: 0.04, F1 Score: 0.2610
# Threshold: 0.05, F1 Score: 0.2734
# Threshold: 0.06, F1 Score: 0.2866
# Threshold: 0.07, F1 Score: 0.2998
# Threshold: 0.08, F1 Score: 0.3125
# Threshold: 0.09, F1 Score: 0.3254
# Threshold: 0.10, F1 Score: 0.3378
# Threshold: 0.11, F1 Score: 0.3500
# Threshold: 0.12, F1 Score: 0.3618
# Threshold: 0.13, F1 Score: 0.3731
# Threshold: 0.14, F1 Score: 0.3819
# Threshold: 0.15, F1 Score: 0.3908
# Threshold: 0.16, F1 Score: 0.3999
# Threshold: 0.17, F1 Score: 0.4061
# Threshold: 0.18, F1 Score: 0.4118
# Threshold: 0.19, F1 Score: 0.4162
# Threshold: 0.20, F1 Score: 0.4193
# Threshold: 0.21, F1 Score: 0.4218
# Threshold: 0.22, F1 Score: 0.4215
# Threshold: 0.23, F1 Score: 0.4209
# Threshold: 0.24, F1 Score: 0.4186
# Threshold: 0.25, F1 Score: 0.4150
# Threshold: 0.26, F1 Score: 0.4098
# Threshold: 0.27, F1 Score: 0.4038
# Threshold: 0.28, F1 Score: 0.3957
# Threshold: 0.29, F1 Score: 0.3871
# Threshold: 0.30, F1 Score: 0.3758
# Threshold: 0.31, F1 Score: 0.3639
# Threshold: 0.32, F1 Score: 0.3518
# Threshold: 0.33, F1 Score: 0.3388
# Threshold: 0.34, F1 Score: 0.3259
# Threshold: 0.35, F1 Score: 0.3118
# Threshold: 0.36, F1 Score: 0.2961
# Threshold: 0.37, F1 Score: 0.2786
# Threshold: 0.38, F1 Score: 0.2630
# Threshold: 0.39, F1 Score: 0.2480
# Threshold: 0.40, F1 Score: 0.2307
# Threshold: 0.41, F1 Score: 0.2154
